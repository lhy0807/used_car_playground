# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
usa = gpd.read_file('zipcodes.shp')

# %% [markdown]
# # Remove some ZIP Codes that are too far from the continent
# we are setting Seattle,WA as top left corner and Miami,FL as bottom right corner
# This is previously done, and result is saved in the shape file

# %%
'''def find_outside(geomlist):
    for a in geomlist:
        if a[1] < 22:
            return 'Yes'
    return 'No'

usa['geomlist'] = usa['geometry'].apply(lambda x: list(x[0].exterior.coords))
usa['detect'] = usa['geomlist'].apply(find_outside)
usa = usa.drop(usa[usa.detect == 'Yes'].index)
usa = usa.drop(['geomlist','detect'],axis=1)
usa.to_file("zipcodes.shp")
'''

# %% [markdown]
# # Focus on NY state right now

# %%
ny = usa[usa['STATE'] == 'NY']
plt.rcParams['figure.figsize'] = [20, 10]
ny.plot()

# %% [markdown]
# # Create a Choropleth Maps according to average price
# we focus on 2015 BMW 3 Series at this point

# %%
with open('usedcar/usedcar.json') as f:
    data = json.load(f)
ny.insert(3,'price',0)

# %%
#first collect data and calculate avg price
#then put into dataframe
avg_price = {}
counter = {}

#initialize
for car in data:
    avg_price[car['zip']] = 0
    counter[car['zip']] = 0

for car in data:
    avg_price[car['zip']] = int(car['price'].replace(',', ''))
    counter[car['zip']] += 1

for i in avg_price:
    avg_price[i] /= counter[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-98e5fd6e02ab> in <module>
#      10
#      11 for car in data:
# ---> 12     avg_price[car['zip']] = int(car['price'])
#      13     counter[car['zip']] += 1
#      14
#
# ValueError: invalid literal for int() with base 10: '11,495'

# %%
ny
# Out:
#      ZIP_CODE         PO_NAME STATE  price  POPULATION   POP_SQMI   SQMI  \
# 1700    06390  Fishers Island    NY      0       236.0      56.32   4.19
# 2403    10001        New York    NY      0     27628.0   42504.62   0.65
# 2404    10002        New York    NY      0     82227.0   72128.95   1.14
# 2405    10003        New York    NY      0     57453.0  102594.64   0.56
# 2406    10004        New York    NY      0      3545.0    6817.31   0.52
# ...       ...             ...   ...    ...         ...        ...    ...
# 4038    14898        Woodhull    NY      0      1565.0      27.50  56.90
# 4039    14901          Elmira    NY      0     15738.0     431.53  36.47
# 4040    14903          Elmira    NY      0      7676.0     335.64  22.87
# 4041    14904          Elmira    NY      0     15690.0    2806.80   5.59
# 4042    14905          Elmira    NY      0      8422.0    2049.15   4.11
#
#       Shape_Leng  Shape_Area  \
# 1700    0.446554    0.001166
# 2403    0.072254    0.000178
# 2404    0.084659    0.000315
# 2405    0.059762    0.000155
# 2406    0.123589    0.000144
# ...          ...         ...
# 4038    0.818591    0.016027
# 4039    0.897824    0.010274
# 4040    0.489486    0.006450
# 4041    0.266178    0.001576
# 4042    0.233797    0.001159
#
#                                                geometry
# 1700  MULTIPOLYGON (((-72.03855 41.25006, -72.03855 ...
# 2403  POLYGON ((-74.01068 40.75104, -74.01056 40.751...
# 2404  POLYGON ((-73.99759 40.71406, -73.99753 40.714...
# 2405  POLYGON ((-73.99696 40.73143, -73.99660 40.731...
# 2406  MULTIPOLYGON (((-74.04725 40.69082, -74.04725 ...
# ...                                                 ...
# 4038  POLYGON ((-77.52170 42.01765, -77.52161 42.017...
# 4039  POLYGON ((-76.83346 42.10562, -76.83343 42.105...
# 4040  POLYGON ((-76.95415 42.12358, -76.95408 42.123...
# 4041  POLYGON ((-76.84743 42.07228, -76.84663 42.072...
# 4042  POLYGON ((-76.87668 42.08461, -76.87327 42.087...
#
# [1641 rows x 10 columns]
